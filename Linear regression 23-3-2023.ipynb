# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,x_vars=['TV','radio','newspaper'],y_vars='sales',kind='scatter')
plt.show()

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_ebcaa_row0_col0, #T_ebcaa_row1_col1, #T_ebcaa_row2_col2, #T_ebcaa_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ebcaa_row0_col1, #T_ebcaa_row0_col2, #T_ebcaa_row1_col0, #T_ebcaa_row2_col0, #T_ebcaa_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ebcaa_row0_col3 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_ebcaa_row1_col2 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_ebcaa_row1_col3 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_ebcaa_row2_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_ebcaa_row3_col0 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_ebcaa_row3_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_ebcaa_row3_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# </style>
# <table id="T_ebcaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebcaa_level0_col0" class="col_heading level0 col0" >TV</th>
#       <th id="T_ebcaa_level0_col1" class="col_heading level0 col1" >radio</th>
#       <th id="T_ebcaa_level0_col2" class="col_heading level0 col2" >newspaper</th>
#       <th id="T_ebcaa_level0_col3" class="col_heading level0 col3" >sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebcaa_level0_row0" class="row_heading level0 row0" >TV</th>
#       <td id="T_ebcaa_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ebcaa_row0_col1" class="data row0 col1" >0.054809</td>
#       <td id="T_ebcaa_row0_col2" class="data row0 col2" >0.056648</td>
#       <td id="T_ebcaa_row0_col3" class="data row0 col3" >0.782224</td>
#     </tr>
#     <tr>
#       <th id="T_ebcaa_level0_row1" class="row_heading level0 row1" >radio</th>
#       <td id="T_ebcaa_row1_col0" class="data row1 col0" >0.054809</td>
#       <td id="T_ebcaa_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ebcaa_row1_col2" class="data row1 col2" >0.354104</td>
#       <td id="T_ebcaa_row1_col3" class="data row1 col3" >0.576223</td>
#     </tr>
#     <tr>
#       <th id="T_ebcaa_level0_row2" class="row_heading level0 row2" >newspaper</th>
#       <td id="T_ebcaa_row2_col0" class="data row2 col0" >0.056648</td>
#       <td id="T_ebcaa_row2_col1" class="data row2 col1" >0.354104</td>
#       <td id="T_ebcaa_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ebcaa_row2_col3" class="data row2 col3" >0.228299</td>
#     </tr>
#     <tr>
#       <th id="T_ebcaa_level0_row3" class="row_heading level0 row3" >sales</th>
#       <td id="T_ebcaa_row3_col0" class="data row3 col0" >0.782224</td>
#       <td id="T_ebcaa_row3_col1" class="data row3 col1" >0.576223</td>
#       <td id="T_ebcaa_row3_col2" class="data row3 col2" >0.228299</td>
#       <td id="T_ebcaa_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
x=df.iloc[:,:-1]
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
r=r2_score(ytest,ypred)

# %%
mae
# Out:
# 1.0548328405073313

# %%
mse
# Out:
# 1.9289249074665722

# %%
r
# Out:
# 0.9224605706201435

# %%
lr.intercept_
# Out:
# 2.9372157346906107

# %%
lr.coef_
# Out:
# array([0.04695205, 0.17658644, 0.00185115])

# %%
pd.DataFrame(lr.coef_,index=x.columns,columns=["coefficients"])
# Out:
#            coefficients
# TV             0.046952
# radio          0.176586
# newspaper      0.001851

# %%
residual=ytest-ypred

# %%
sns.distplot(residual)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
x=df.iloc[:,:-2]
x
# Out:
#         TV  radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]

# %%
y=df.iloc[:,-2]
y
# Out:
# 0      69.2
# 1      45.1
# 2      69.3
# 3      58.5
# 4      58.4
#        ...
# 195    13.8
# 196     8.1
# 197     6.4
# 198    66.2
# 199     8.7
# Name: newspaper, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
r=r2_score(ytest,ypred)

# %%
r
# Out:
# 0.01469291352696167

# %%
sns.distplot((ytest-ypred))
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures(degree=2)
xtrainnp=pf.fit_transform(xtrain)

# %%
xtestp=pf.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrainnp,ytrain)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(xtestp)

# %%
sns.pairplot(df,x_vars=['TV','radio','newspaper'],y_vars='sales',kind='scatter')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
r=r2_score(ytest,ypred)

# %%
r
# Out:
# 0.01469291352696167

# %%
sns.pairplot(df,x_vars=['TV','radio','newspaper'],y_vars='sales',kind='scatter')
